# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __OSSAI DANIEL__
# Data Scientist

# %% [markdown]
# _I am interested in Data Science because, i want to use knowledge gained to contribute in the fields of Biotechnology_

# %% [markdown]
# ### The code in cell 5, should be able to sum up a particular number leaving a correct out put.

# %%
1+1
# Out:
# 2

# %% [markdown]
# Below, are names of some African countries:
# - NIgeria
# - Senegal
# - Mali
# ***********
# Top football players in history
# 1. Pele
# 1. C. Ronaldo
# 1. L. Messi
